# %%
import pickle

# %%
x = pickle.load(open('x.pkl', 'rb'))
y = pickle.load(open('y.pkl', 'rb'))

# %%
x
# Out:
# array([[[[  7,  12,  10],
#          [  8,  11,   2],
#          [ 20,  24,  29],
#          ...,
#          [ 79,  60,  52],
#          [ 83,  58,  48],
#          [ 99,  69,  54]],
#
#         [[  7,  12,  10],
#          [ 12,  15,   6],
#          [ 18,  22,  27],
#          ...,
#          [ 89,  61,  51],
#          [ 94,  62,  49],
#          [103,  71,  58]],
#
#         [[ 10,  15,  13],
#          [ 12,  15,   6],
#          [ 15,  19,  24],
#          ...,
#          [ 87,  61,  47],
#          [ 83,  59,  41],
#          [103,  72,  62]],
#
#         ...,
#
#         [[158, 141, 137],
#          [100,  91,  88],
#          [110, 109, 109],
#          ...,
#          [139, 125, 119],
#          [208, 193, 184],
#          [217, 197, 179]],
#
#         [[113, 105, 108],
#          [106, 101, 103],
#          [109, 104, 105],
#          ...,
#          [ 98,  86,  86],
#          [ 95,  86,  83],
#          [176, 159, 153]],
#
#         [[122, 110, 112],
#          [115, 106, 109],
#          [113, 106, 111],
#          ...,
#          [110, 100,  92],
#          [100,  89,  85],
#          [108,  98,  91]]],
#
#
#        [[[ 50,  48,  47],
#          [ 45,  43,  42],
#          [ 48,  46,  45],
#          ...,
#          [ 37, 119, 197],
#          [ 42, 124, 202],
#          [ 51, 127, 199]],
#
#         [[ 56,  54,  53],
#          [ 58,  56,  55],
#          [ 48,  46,  45],
#          ...,
#          [ 27, 114, 194],
#          [ 34, 121, 201],
#          [ 59, 134, 208]],
#
#         [[ 55,  53,  52],
#          [ 51,  49,  48],
#          [ 49,  47,  46],
#          ...,
#          [ 41, 122, 207],
#          [ 40, 120, 205],
#          [ 59, 133, 211]],
#
#         ...,
#
#         [[ 23,  88, 133],
#          [ 25,  85, 139],
#          [ 11,  68, 122],
#          ...,
#          [  0,  55, 134],
#          [ 11,  45, 104],
#          [  9,  45, 109]],
#
#         [[ 17,  66, 110],
#          [  0,  45,  99],
#          [ 40,  90, 142],
#          ...,
#          [  0,  52, 129],
#          [ 12,  47, 110],
#          [ 11,  48, 110]],
#
#         [[ 27,  95, 140],
#          [ 17,  93, 145],
#          [ 20,  99, 150],
#          ...,
#          [ 13,  58, 132],
#          [ 16,  51, 119],
#          [ 13,  57, 118]]],
#
#
#        [[[ 72,  85,  65],
#          [ 61,  75,  95],
#          [ 55,  71, 104],
#          ...,
#          [ 31,  58,  79],
#          [ 10,  37,  58],
#          [ 19,  46,  67]],
#
#         [[113, 126,  84],
#          [ 64,  83,  85],
#          [ 58,  78, 109],
#          ...,
#          [ 40,  67,  88],
#          [ 15,  42,  63],
#          [  9,  36,  57]],
#
#         [[143, 148,  83],
#          [ 83, 100,  77],
#          [ 70,  90, 107],
#          ...,
#          [ 40,  67,  88],
#          [ 25,  51,  72],
#          [ 16,  43,  64]],
#
#         ...,
#
#         [[103, 125, 153],
#          [ 74,  93, 114],
#          [ 20,  29,  26],
#          ...,
#          [  0,  28,  75],
#          [ 12,  38,  85],
#          [  3,  28,  72]],
#
#         [[ 94, 115, 146],
#          [ 75,  95, 126],
#          [ 11,  22,  28],
#          ...,
#          [  0,  27,  74],
#          [  7,  30,  78],
#          [  4,  30,  76]],
#
#         [[ 99, 120, 151],
#          [ 82, 103, 135],
#          [ 14,  26,  36],
#          ...,
#          [  3,  33,  80],
#          [ 11,  33,  81],
#          [  4,  30,  77]]],
#
#
#        ...,
#
#
#        [[[115, 119, 113],
#          [111, 115, 109],
#          [114, 118, 112],
#          ...,
#          [130, 135, 133],
#          [129, 134, 132],
#          [124, 132, 122]],
#
#         [[109, 113, 108],
#          [108, 112, 107],
#          [106, 110, 105],
#          ...,
#          [121, 126, 124],
#          [124, 129, 127],
#          [121, 129, 119]],
#
#         [[ 97, 100,  97],
#          [107, 110, 108],
#          [105, 109, 106],
#          ...,
#          [118, 122, 121],
#          [120, 125, 123],
#          [116, 123, 117]],
#
#         ...,
#
#         [[ 25,  29,  53],
#          [ 21,  25,  49],
#          [ 16,  20,  44],
#          ...,
#          [  4,   6,  16],
#          [  9,  10,  20],
#          [ 33,  16,  19]],
#
#         [[ 19,  23,  46],
#          [ 17,  22,  44],
#          [ 15,  20,  42],
#          ...,
#          [  4,  10,  19],
#          [ 11,  12,  16],
#          [ 38,  17,  18]],
#
#         [[ 19,  25,  44],
#          [ 19,  25,  44],
#          [ 18,  24,  43],
#          ...,
#          [114, 121, 130],
#          [ 54,  61,  70],
#          [ 36,  21,  19]]],
#
#
#        [[[153, 163, 162],
#          [160, 172, 166],
#          [151, 165, 153],
#          ...,
#          [164, 174, 172],
#          [161, 172, 169],
#          [168, 173, 171]],
#
#         [[155, 169, 158],
#          [156, 169, 161],
#          [157, 168, 165],
#          ...,
#          [162, 173, 170],
#          [162, 173, 170],
#          [166, 173, 170]],
#
#         [[153, 167, 155],
#          [148, 161, 153],
#          [154, 165, 164],
#          ...,
#          [163, 175, 171],
#          [164, 175, 172],
#          [164, 173, 170]],
#
#         ...,
#
#         [[ 66,  52,  53],
#          [ 58,  47,  49],
#          [ 58,  53,  43],
#          ...,
#          [162, 175, 172],
#          [151, 168, 165],
#          [163, 179, 173]],
#
#         [[ 54,  46,  44],
#          [ 40,  39,  26],
#          [ 55,  51,  33],
#          ...,
#          [140, 156, 161],
#          [160, 172, 175],
#          [149, 154, 163]],
#
#         [[ 43,  38,  35],
#          [ 40,  43,  27],
#          [ 55,  48,  33],
#          ...,
#          [146, 161, 169],
#          [141, 148, 157],
#          [149, 154, 163]]],
#
#
#        [[[247, 253, 253],
#          [247, 246, 246],
#          [255, 254, 255],
#          ...,
#          [255, 255, 255],
#          [248, 248, 248],
#          [246, 246, 246]],
#
#         [[162, 171, 170],
#          [202, 203, 203],
#          [207, 204, 204],
#          ...,
#          [198, 198, 198],
#          [200, 200, 200],
#          [212, 212, 212]],
#
#         [[157, 172, 169],
#          [247, 250, 250],
#          [255, 255, 255],
#          ...,
#          [254, 254, 254],
#          [255, 255, 255],
#          [254, 254, 254]],
#
#         ...,
#
#         [[ 80, 126, 192],
#          [ 64, 118, 197],
#          [ 56, 111, 200],
#          ...,
#          [ 48, 101, 140],
#          [ 42,  84, 120],
#          [125, 144, 149]],
#
#         [[ 76, 114, 171],
#          [ 63, 108, 177],
#          [ 59, 105, 183],
#          ...,
#          [ 50,  99, 146],
#          [ 37,  78, 120],
#          [140, 155, 165]],
#
#         [[ 86, 109, 154],
#          [ 75, 107, 162],
#          [ 75, 111, 173],
#          ...,
#          [ 61, 104, 159],
#          [ 49,  87, 137],
#          [141, 155, 170]]]], dtype=uint8)

# %%
y
# Out:
# array([1, 1, 0, ..., 1, 1, 0])

# %%
# Normalizing 'x' data
x = x/255

# %%
# After Normalization "x" data
x
# Out:
# array([[[[0.02745098, 0.04705882, 0.03921569],
#          [0.03137255, 0.04313725, 0.00784314],
#          [0.07843137, 0.09411765, 0.11372549],
#          ...,
#          [0.30980392, 0.23529412, 0.20392157],
#          [0.3254902 , 0.22745098, 0.18823529],
#          [0.38823529, 0.27058824, 0.21176471]],
#
#         [[0.02745098, 0.04705882, 0.03921569],
#          [0.04705882, 0.05882353, 0.02352941],
#          [0.07058824, 0.08627451, 0.10588235],
#          ...,
#          [0.34901961, 0.23921569, 0.2       ],
#          [0.36862745, 0.24313725, 0.19215686],
#          [0.40392157, 0.27843137, 0.22745098]],
#
#         [[0.03921569, 0.05882353, 0.05098039],
#          [0.04705882, 0.05882353, 0.02352941],
#          [0.05882353, 0.0745098 , 0.09411765],
#          ...,
#          [0.34117647, 0.23921569, 0.18431373],
#          [0.3254902 , 0.23137255, 0.16078431],
#          [0.40392157, 0.28235294, 0.24313725]],
#
#         ...,
#
#         [[0.61960784, 0.55294118, 0.5372549 ],
#          [0.39215686, 0.35686275, 0.34509804],
#          [0.43137255, 0.42745098, 0.42745098],
#          ...,
#          [0.54509804, 0.49019608, 0.46666667],
#          [0.81568627, 0.75686275, 0.72156863],
#          [0.85098039, 0.77254902, 0.70196078]],
#
#         [[0.44313725, 0.41176471, 0.42352941],
#          [0.41568627, 0.39607843, 0.40392157],
#          [0.42745098, 0.40784314, 0.41176471],
#          ...,
#          [0.38431373, 0.3372549 , 0.3372549 ],
#          [0.37254902, 0.3372549 , 0.3254902 ],
#          [0.69019608, 0.62352941, 0.6       ]],
#
#         [[0.47843137, 0.43137255, 0.43921569],
#          [0.45098039, 0.41568627, 0.42745098],
#          [0.44313725, 0.41568627, 0.43529412],
#          ...,
#          [0.43137255, 0.39215686, 0.36078431],
#          [0.39215686, 0.34901961, 0.33333333],
#          [0.42352941, 0.38431373, 0.35686275]]],
#
#
#        [[[0.19607843, 0.18823529, 0.18431373],
#          [0.17647059, 0.16862745, 0.16470588],
#          [0.18823529, 0.18039216, 0.17647059],
#          ...,
#          [0.14509804, 0.46666667, 0.77254902],
#          [0.16470588, 0.48627451, 0.79215686],
#          [0.2       , 0.49803922, 0.78039216]],
#
#         [[0.21960784, 0.21176471, 0.20784314],
#          [0.22745098, 0.21960784, 0.21568627],
#          [0.18823529, 0.18039216, 0.17647059],
#          ...,
#          [0.10588235, 0.44705882, 0.76078431],
#          [0.13333333, 0.4745098 , 0.78823529],
#          [0.23137255, 0.5254902 , 0.81568627]],
#
#         [[0.21568627, 0.20784314, 0.20392157],
#          [0.2       , 0.19215686, 0.18823529],
#          [0.19215686, 0.18431373, 0.18039216],
#          ...,
#          [0.16078431, 0.47843137, 0.81176471],
#          [0.15686275, 0.47058824, 0.80392157],
#          [0.23137255, 0.52156863, 0.82745098]],
#
#         ...,
#
#         [[0.09019608, 0.34509804, 0.52156863],
#          [0.09803922, 0.33333333, 0.54509804],
#          [0.04313725, 0.26666667, 0.47843137],
#          ...,
#          [0.        , 0.21568627, 0.5254902 ],
#          [0.04313725, 0.17647059, 0.40784314],
#          [0.03529412, 0.17647059, 0.42745098]],
#
#         [[0.06666667, 0.25882353, 0.43137255],
#          [0.        , 0.17647059, 0.38823529],
#          [0.15686275, 0.35294118, 0.55686275],
#          ...,
#          [0.        , 0.20392157, 0.50588235],
#          [0.04705882, 0.18431373, 0.43137255],
#          [0.04313725, 0.18823529, 0.43137255]],
#
#         [[0.10588235, 0.37254902, 0.54901961],
#          [0.06666667, 0.36470588, 0.56862745],
#          [0.07843137, 0.38823529, 0.58823529],
#          ...,
#          [0.05098039, 0.22745098, 0.51764706],
#          [0.0627451 , 0.2       , 0.46666667],
#          [0.05098039, 0.22352941, 0.4627451 ]]],
#
#
#        [[[0.28235294, 0.33333333, 0.25490196],
#          [0.23921569, 0.29411765, 0.37254902],
#          [0.21568627, 0.27843137, 0.40784314],
#          ...,
#          [0.12156863, 0.22745098, 0.30980392],
#          [0.03921569, 0.14509804, 0.22745098],
#          [0.0745098 , 0.18039216, 0.2627451 ]],
#
#         [[0.44313725, 0.49411765, 0.32941176],
#          [0.25098039, 0.3254902 , 0.33333333],
#          [0.22745098, 0.30588235, 0.42745098],
#          ...,
#          [0.15686275, 0.2627451 , 0.34509804],
#          [0.05882353, 0.16470588, 0.24705882],
#          [0.03529412, 0.14117647, 0.22352941]],
#
#         [[0.56078431, 0.58039216, 0.3254902 ],
#          [0.3254902 , 0.39215686, 0.30196078],
#          [0.2745098 , 0.35294118, 0.41960784],
#          ...,
#          [0.15686275, 0.2627451 , 0.34509804],
#          [0.09803922, 0.2       , 0.28235294],
#          [0.0627451 , 0.16862745, 0.25098039]],
#
#         ...,
#
#         [[0.40392157, 0.49019608, 0.6       ],
#          [0.29019608, 0.36470588, 0.44705882],
#          [0.07843137, 0.11372549, 0.10196078],
#          ...,
#          [0.        , 0.10980392, 0.29411765],
#          [0.04705882, 0.14901961, 0.33333333],
#          [0.01176471, 0.10980392, 0.28235294]],
#
#         [[0.36862745, 0.45098039, 0.57254902],
#          [0.29411765, 0.37254902, 0.49411765],
#          [0.04313725, 0.08627451, 0.10980392],
#          ...,
#          [0.        , 0.10588235, 0.29019608],
#          [0.02745098, 0.11764706, 0.30588235],
#          [0.01568627, 0.11764706, 0.29803922]],
#
#         [[0.38823529, 0.47058824, 0.59215686],
#          [0.32156863, 0.40392157, 0.52941176],
#          [0.05490196, 0.10196078, 0.14117647],
#          ...,
#          [0.01176471, 0.12941176, 0.31372549],
#          [0.04313725, 0.12941176, 0.31764706],
#          [0.01568627, 0.11764706, 0.30196078]]],
#
#
#        ...,
#
#
#        [[[0.45098039, 0.46666667, 0.44313725],
#          [0.43529412, 0.45098039, 0.42745098],
#          [0.44705882, 0.4627451 , 0.43921569],
#          ...,
#          [0.50980392, 0.52941176, 0.52156863],
#          [0.50588235, 0.5254902 , 0.51764706],
#          [0.48627451, 0.51764706, 0.47843137]],
#
#         [[0.42745098, 0.44313725, 0.42352941],
#          [0.42352941, 0.43921569, 0.41960784],
#          [0.41568627, 0.43137255, 0.41176471],
#          ...,
#          [0.4745098 , 0.49411765, 0.48627451],
#          [0.48627451, 0.50588235, 0.49803922],
#          [0.4745098 , 0.50588235, 0.46666667]],
#
#         [[0.38039216, 0.39215686, 0.38039216],
#          [0.41960784, 0.43137255, 0.42352941],
#          [0.41176471, 0.42745098, 0.41568627],
#          ...,
#          [0.4627451 , 0.47843137, 0.4745098 ],
#          [0.47058824, 0.49019608, 0.48235294],
#          [0.45490196, 0.48235294, 0.45882353]],
#
#         ...,
#
#         [[0.09803922, 0.11372549, 0.20784314],
#          [0.08235294, 0.09803922, 0.19215686],
#          [0.0627451 , 0.07843137, 0.17254902],
#          ...,
#          [0.01568627, 0.02352941, 0.0627451 ],
#          [0.03529412, 0.03921569, 0.07843137],
#          [0.12941176, 0.0627451 , 0.0745098 ]],
#
#         [[0.0745098 , 0.09019608, 0.18039216],
#          [0.06666667, 0.08627451, 0.17254902],
#          [0.05882353, 0.07843137, 0.16470588],
#          ...,
#          [0.01568627, 0.03921569, 0.0745098 ],
#          [0.04313725, 0.04705882, 0.0627451 ],
#          [0.14901961, 0.06666667, 0.07058824]],
#
#         [[0.0745098 , 0.09803922, 0.17254902],
#          [0.0745098 , 0.09803922, 0.17254902],
#          [0.07058824, 0.09411765, 0.16862745],
#          ...,
#          [0.44705882, 0.4745098 , 0.50980392],
#          [0.21176471, 0.23921569, 0.2745098 ],
#          [0.14117647, 0.08235294, 0.0745098 ]]],
#
#
#        [[[0.6       , 0.63921569, 0.63529412],
#          [0.62745098, 0.6745098 , 0.65098039],
#          [0.59215686, 0.64705882, 0.6       ],
#          ...,
#          [0.64313725, 0.68235294, 0.6745098 ],
#          [0.63137255, 0.6745098 , 0.6627451 ],
#          [0.65882353, 0.67843137, 0.67058824]],
#
#         [[0.60784314, 0.6627451 , 0.61960784],
#          [0.61176471, 0.6627451 , 0.63137255],
#          [0.61568627, 0.65882353, 0.64705882],
#          ...,
#          [0.63529412, 0.67843137, 0.66666667],
#          [0.63529412, 0.67843137, 0.66666667],
#          [0.65098039, 0.67843137, 0.66666667]],
#
#         [[0.6       , 0.65490196, 0.60784314],
#          [0.58039216, 0.63137255, 0.6       ],
#          [0.60392157, 0.64705882, 0.64313725],
#          ...,
#          [0.63921569, 0.68627451, 0.67058824],
#          [0.64313725, 0.68627451, 0.6745098 ],
#          [0.64313725, 0.67843137, 0.66666667]],
#
#         ...,
#
#         [[0.25882353, 0.20392157, 0.20784314],
#          [0.22745098, 0.18431373, 0.19215686],
#          [0.22745098, 0.20784314, 0.16862745],
#          ...,
#          [0.63529412, 0.68627451, 0.6745098 ],
#          [0.59215686, 0.65882353, 0.64705882],
#          [0.63921569, 0.70196078, 0.67843137]],
#
#         [[0.21176471, 0.18039216, 0.17254902],
#          [0.15686275, 0.15294118, 0.10196078],
#          [0.21568627, 0.2       , 0.12941176],
#          ...,
#          [0.54901961, 0.61176471, 0.63137255],
#          [0.62745098, 0.6745098 , 0.68627451],
#          [0.58431373, 0.60392157, 0.63921569]],
#
#         [[0.16862745, 0.14901961, 0.1372549 ],
#          [0.15686275, 0.16862745, 0.10588235],
#          [0.21568627, 0.18823529, 0.12941176],
#          ...,
#          [0.57254902, 0.63137255, 0.6627451 ],
#          [0.55294118, 0.58039216, 0.61568627],
#          [0.58431373, 0.60392157, 0.63921569]]],
#
#
#        [[[0.96862745, 0.99215686, 0.99215686],
#          [0.96862745, 0.96470588, 0.96470588],
#          [1.        , 0.99607843, 1.        ],
#          ...,
#          [1.        , 1.        , 1.        ],
#          [0.97254902, 0.97254902, 0.97254902],
#          [0.96470588, 0.96470588, 0.96470588]],
#
#         [[0.63529412, 0.67058824, 0.66666667],
#          [0.79215686, 0.79607843, 0.79607843],
#          [0.81176471, 0.8       , 0.8       ],
#          ...,
#          [0.77647059, 0.77647059, 0.77647059],
#          [0.78431373, 0.78431373, 0.78431373],
#          [0.83137255, 0.83137255, 0.83137255]],
#
#         [[0.61568627, 0.6745098 , 0.6627451 ],
#          [0.96862745, 0.98039216, 0.98039216],
#          [1.        , 1.        , 1.        ],
#          ...,
#          [0.99607843, 0.99607843, 0.99607843],
#          [1.        , 1.        , 1.        ],
#          [0.99607843, 0.99607843, 0.99607843]],
#
#         ...,
#
#         [[0.31372549, 0.49411765, 0.75294118],
#          [0.25098039, 0.4627451 , 0.77254902],
#          [0.21960784, 0.43529412, 0.78431373],
#          ...,
#          [0.18823529, 0.39607843, 0.54901961],
#          [0.16470588, 0.32941176, 0.47058824],
#          [0.49019608, 0.56470588, 0.58431373]],
#
#         [[0.29803922, 0.44705882, 0.67058824],
#          [0.24705882, 0.42352941, 0.69411765],
#          [0.23137255, 0.41176471, 0.71764706],
#          ...,
#          [0.19607843, 0.38823529, 0.57254902],
#          [0.14509804, 0.30588235, 0.47058824],
#          [0.54901961, 0.60784314, 0.64705882]],
#
#         [[0.3372549 , 0.42745098, 0.60392157],
#          [0.29411765, 0.41960784, 0.63529412],
#          [0.29411765, 0.43529412, 0.67843137],
#          ...,
#          [0.23921569, 0.40784314, 0.62352941],
#          [0.19215686, 0.34117647, 0.5372549 ],
#          [0.55294118, 0.60784314, 0.66666667]]]])

# %%
x.shape
# Out:
# (23000, 100, 100, 3)

# %%
y.shape
# Out:
# (23000,)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense,BatchNormalization, Dropout

# %%
# Designing the Model
model = Sequential()

model.add(Conv2D(64, (3,3), activation = 'relu', input_shape=(100, 100, 3)))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(64, (3,3), activation = 'relu'))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(64, (3,3), activation = 'relu'))
model.add(MaxPooling2D((2,2)))


model.add(Flatten())
model.add(Dense(128, input_shape = x.shape[1:], activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))
# Out:
# C:\Users\Syeds\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# C:\Users\Syeds\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# Fitting the Model

history = model.fit(x, y, epochs = 5, validation_split = 0.1, batch_size = 64)
# Out:
# Epoch 1/5
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 149s 446ms/step - accuracy: 0.5704 - loss: 0.6700 - val_accuracy: 0.7091 - val_loss: 0.5551
# Epoch 2/5
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 108s 333ms/step - accuracy: 0.7496 - loss: 0.5083 - val_accuracy: 0.7909 - val_loss: 0.4482
# Epoch 3/5
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 111s 341ms/step - accuracy: 0.7956 - loss: 0.4367 - val_accuracy: 0.7770 - val_loss: 0.4645
# Epoch 4/5
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 116s 356ms/step - accuracy: 0.8245 - loss: 0.3910 - val_accuracy: 0.8226 - val_loss: 0.3861
# Epoch 5/5
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 141s 434ms/step - accuracy: 0.8496 - loss: 0.3403 - val_accuracy: 0.8287 - val_loss: 0.3850

# %%
import numpy as np
import cv2
import os
import random
import matplotlib.pyplot as plt
import pickle

# %%
X_sample = np.loadtxt('input_test.csv', delimiter = ',')

# %%
Y_sample = np.loadtxt('labels_test.csv', delimiter = ',')

# %%
print("Shape of X_sample:", X_sample.shape)
print("Shape of Y_sample:", Y_sample.shape)
# Out:
# Shape of X_sample: (400, 30000)
# Shape of Y_sample: (400,)

# %%
X_sample = X_sample.reshape(len(X_sample), 100, 100, 3)
Y_sample = Y_sample.reshape(len(Y_sample), 1)

# %%
X_sample[1,:]
# Out:
# array([[[223., 211., 163.],
#         [223., 209., 160.],
#         [244., 228., 179.],
#         ...,
#         [252., 253., 255.],
#         [254., 255., 255.],
#         [245., 246., 250.]],
#
#        [[255., 246., 206.],
#         [254., 241., 199.],
#         [255., 251., 206.],
#         ...,
#         [252., 252., 250.],
#         [255., 255., 253.],
#         [255., 255., 253.]],
#
#        [[255., 249., 222.],
#         [254., 243., 213.],
#         [255., 246., 212.],
#         ...,
#         [241., 239., 227.],
#         [165., 163., 151.],
#         [145., 143., 131.]],
#
#        ...,
#
#        [[136., 131., 128.],
#         [174., 170., 167.],
#         [181., 177., 176.],
#         ...,
#         [ 47.,  50.,  55.],
#         [ 46.,  49.,  56.],
#         [ 47.,  50.,  57.]],
#
#        [[173., 165., 162.],
#         [182., 177., 174.],
#         [167., 162., 159.],
#         ...,
#         [ 70.,  74.,  77.],
#         [ 70.,  73.,  78.],
#         [ 70.,  73.,  78.]],
#
#        [[141., 133., 130.],
#         [133., 125., 122.],
#         [121., 116., 113.],
#         ...,
#         [ 69.,  73.,  76.],
#         [ 69.,  72.,  77.],
#         [ 70.,  73.,  78.]]])

# %%
X_sample = X_sample/255
X_sample[0]
# Out:
# array([[[0.4627451 , 0.32156863, 0.37647059],
#         [0.42745098, 0.27843137, 0.32156863],
#         [0.45490196, 0.30196078, 0.30588235],
#         ...,
#         [0.66666667, 0.5254902 , 0.39215686],
#         [0.64705882, 0.50588235, 0.36470588],
#         [0.63921569, 0.49803922, 0.35686275]],
#
#        [[0.37254902, 0.24313725, 0.28627451],
#         [0.40784314, 0.27058824, 0.29803922],
#         [0.43137255, 0.29411765, 0.28627451],
#         ...,
#         [0.68235294, 0.54117647, 0.4       ],
#         [0.66666667, 0.5254902 , 0.38431373],
#         [0.65490196, 0.51764706, 0.36862745]],
#
#        [[0.69411765, 0.58039216, 0.6       ],
#         [0.70980392, 0.59215686, 0.6       ],
#         [0.67843137, 0.55686275, 0.5372549 ],
#         ...,
#         [0.68627451, 0.55294118, 0.40392157],
#         [0.67058824, 0.5372549 , 0.38823529],
#         [0.65882353, 0.52941176, 0.36862745]],
#
#        ...,
#
#        [[0.24705882, 0.23529412, 0.30196078],
#         [0.25490196, 0.25098039, 0.31372549],
#         [0.25490196, 0.2627451 , 0.32156863],
#         ...,
#         [0.58039216, 0.38431373, 0.24705882],
#         [0.60784314, 0.38431373, 0.16862745],
#         [0.56862745, 0.32941176, 0.0745098 ]],
#
#        [[0.22745098, 0.21568627, 0.28235294],
#         [0.23529412, 0.23137255, 0.29411765],
#         [0.23529412, 0.24313725, 0.30196078],
#         ...,
#         [0.51764706, 0.32156863, 0.19215686],
#         [0.56078431, 0.3372549 , 0.12156863],
#         [0.54117647, 0.30196078, 0.05490196]],
#
#        [[0.22745098, 0.21568627, 0.28235294],
#         [0.22745098, 0.22352941, 0.28627451],
#         [0.21568627, 0.22352941, 0.28235294],
#         ...,
#         [0.48235294, 0.28627451, 0.15686275],
#         [0.54509804, 0.32156863, 0.11372549],
#         [0.54901961, 0.30980392, 0.0627451 ]]])

# %%
model.evaluate(X_sample, Y_sample)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.1629 - loss: 1.9806
# [1.7712548971176147, 0.21250000596046448]

# %%
idx= random.randint(0, len(Y_sample)-1)
plt.imshow(X_sample[idx,:])
plt.axis('off')
plt.show()

Y_predict = model.predict(X_sample[idx,:].reshape(1, 100, 100,3))
Y_predict = (Y_predict < 0.5).astype(int)

if (Y_predict == 0).all():
    pred = 'DOG'
else:
    pred = 'CAT'
print("Our Model says it is a:", pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Our Model says it is a: CAT

# %%
plt.plot(history.history['accuracy'], color = 'red', label = 'train')
plt.plot(history.history['val_accuracy'], color = 'blue', label = 'Validation')
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'], color = 'red', label = 'train')
plt.plot(history.history['val_loss'], color = 'blue', label = 'Validation')
plt.legend()
plt.show()

# %%
model = Sequential()

model.add(Conv2D(64, (3,3), activation = 'relu', input_shape=(100, 100, 3)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(64, (3,3), activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(64, (3,3), activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2)))


model.add(Flatten())
model.add(Dense(128, input_shape = x.shape[1:], activation = 'relu'))
model.add(Dropout(0.1))
model.add(Dense(1, activation = 'sigmoid'))
# Out:
# C:\Users\Syeds\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# C:\Users\Syeds\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)                    │ (None, 98, 98, 64)          │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 98, 98, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 49, 49, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 47, 47, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 47, 47, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 23, 23, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 21, 21, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 21, 21, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 10, 10, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 6400)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │         819,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 895,873 (3.42 MB)
#  Trainable params: 895,489 (3.42 MB)
#  Non-trainable params: 384 (1.50 KB)

# %%
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
history = model.fit(x, y, epochs = 5, validation_split = 0.1, batch_size = 64)
# Out:
# Epoch 1/5
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 240s 718ms/step - accuracy: 0.6472 - loss: 0.8280 - val_accuracy: 0.6030 - val_loss: 0.7919
# Epoch 2/5
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 231s 712ms/step - accuracy: 0.7725 - loss: 0.4793 - val_accuracy: 0.7365 - val_loss: 0.5120
# Epoch 3/5
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 781s 551ms/step - accuracy: 0.8281 - loss: 0.3836 - val_accuracy: 0.7983 - val_loss: 0.4516
# Epoch 4/5
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 173s 533ms/step - accuracy: 0.8724 - loss: 0.3017 - val_accuracy: 0.7857 - val_loss: 0.4705
# Epoch 5/5
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 212s 652ms/step - accuracy: 0.9022 - loss: 0.2370 - val_accuracy: 0.7126 - val_loss: 1.0100

# %%
plt.plot(history.history['accuracy'], color = 'red', label = 'train')
plt.plot(history.history['val_accuracy'], color = 'blue', label = 'Validation')
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'], color = 'red', label = 'train')
plt.plot(history.history['val_loss'], color = 'blue', label = 'Validation')
plt.legend()
plt.show()

# %%
idx2= random.randint(0, len(Y_sample)-1)
plt.imshow(X_sample[idx2,:])
plt.axis('off')
plt.show()

Y_predict2 = model.predict(X_sample[idx2,:].reshape(1, 100, 100,3))
Y_predict2 = (Y_predict2 < 0.5).astype(int)

if (Y_predict2 == 0).all():
    pred = 'DOG'
else:
    pred = 'CAT'
print("Our Model says it is a:", pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Our Model says it is a: CAT

# %%
val_accuracy = history.history['val_accuracy']
print(val_accuracy)
# Out:
# [0.6030434966087341, 0.7365217208862305, 0.7982608675956726, 0.7856521606445312, 0.7126086950302124]

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

# %%
print("Training and Validation Accuracy for each epoch:")
for epoch in range(len(train_accuracy)):
    print(f"Epoch {epoch + 1}:")
    print(f"  Training Accuracy: {train_accuracy[epoch] * 100:.2f}%")
    print(f"  Validation Accuracy: {val_accuracy[epoch] * 100:.2f}%")
# Out:
# Training and Validation Accuracy for each epoch:
# Epoch 1:
#   Training Accuracy: 69.20%
#   Validation Accuracy: 60.30%
# Epoch 2:
#   Training Accuracy: 77.99%
#   Validation Accuracy: 73.65%
# Epoch 3:
#   Training Accuracy: 82.98%
#   Validation Accuracy: 79.83%
# Epoch 4:
#   Training Accuracy: 86.62%
#   Validation Accuracy: 78.57%
# Epoch 5:
#   Training Accuracy: 89.96%
#   Validation Accuracy: 71.26%

# %%
for epoch, accuracy in enumerate(val_accuracy, start=1):
    print(f"Epoch {epoch}: Validation Accuracy = {accuracy * 100:.2f}%")
# Out:
# Epoch 1: Validation Accuracy = 60.30%
# Epoch 2: Validation Accuracy = 73.65%
# Epoch 3: Validation Accuracy = 79.83%
# Epoch 4: Validation Accuracy = 78.57%
# Epoch 5: Validation Accuracy = 71.26%
